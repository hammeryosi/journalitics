# %%
import pandas as pd

# %%
rawTable = pd.read_csv('../data/allHeadlinesNLPRaw.csv')

# %%
def makeCount(col):
    s = {}
    for st in rawTable['persons_raw']:
        if not pd.isnull(st):
            for n in st.split(','):
                if n in s.keys():
                    s[n] += 1
                else:
                    s[n] = 1
    return s

def partialNames(nameCount):
    parNames = {}
    for n in nameCount.keys():
        parts = n.split()
        l = len(parts)
        # general partial names
        if l > 1:
            for i in range(l):
                for j in range(i+1,l+1):
                    p = ' '.join(parts[i:j])
                    if p in nameCount.keys() and p != n:
                        if p in parNames.keys():
                            parNames[p].add(n)
                        else:
                            parNames[p] = set([n])
    for p in parNames.keys():
        parNames[p] = sorted(list(parNames[p]), key=lambda x: nameCount[x], reverse=True)
    return parNames

def longNames(nameCount):
    lNames = {}
    for n in nameCount.keys():
        parts = n.split()
        l = len(parts)
        if l > 2:
            for i in range(l):
                for j in range(i+1,l+1):
                    if j-i > 1:
                        p = ' '.join(parts[i:j])
                        if p in nameCount.keys() and p != n and nameCount[p] > nameCount[n]:
                            if n in lNames.keys():
                                lNames[n].add(p)
                            else:
                                lNames[n] = set([p])
                        p = parts[i] + ' ' + parts[j]
                        if p in nameCount.keys() and p != n and nameCount[p] > nameCount[n]:
                            if n in lNames.keys():
                                lNames[n].add(p)
                            else:
                                lNames[n] = set([p])
                        
                        
    for p in lNames.keys():
        lNames[p] = sorted(list(lNames[p]), key=lambda x: nameCount[x], reverse=True)
    return lNames


def makeConvertDic(parNames):
    convert = {}
    for n in parNames.keys():
        if len(n.split()) == 1: 
            mostCom = parNames[n][0].split()
            # ignore first names
            if mostCom[0] == n:
                convert[n] = None
            # convert last names to most common full name
            if  mostCom[len(mostCom)-1] == n:
                convert[n] = ' '.join(mostCom)
        # reduce long names to two words
        if len(n.split()) > 1:
            for long in parNames[n]:
                convert[long] = n
    return convert
        
def reduceCount(nameCount):
    parNames = partialNames(nameCount)
    convert = makeConvertDic(parNames)
    reducedNameCount = {}
    for n in nameCount.keys():
        if n in convert.keys():
            if convert[n] in reducedNameCount.keys():
                reducedNameCount[convert[n]] += nameCount[n]
            else:
                if convert[n] is not None:
                    reducedNameCount[convert[n]] = nameCount[n]
        else:
            reducedNameCount[n] = nameCount[n]
    return(reducedNameCount)

# %%
nameCount = makeCount(rawTable['persons_raw'])
parNames = partialNames(nameCount)
convert = makeConvertDic(parNames)
    

reducedNameCount = {}
for n in nameCount.keys():
    if n in convert.keys():
        if convert[n] in reducedNameCount.keys():
            reducedNameCount[convert[n]] += nameCount[n]
        else:
            if convert[n] is not None:
                reducedNameCount[convert[n]] = nameCount[n]
    else:
        reducedNameCount[n] = nameCount[n]

# %%
redNames = pd.DataFrame.from_dict(reducedNameCount, orient='index').sort_values(0, ascending=False)
redNames = redNames[redNames[0]>5]
reducedNameCount['Theresa May']
# Out:
# 256

# %%
lNames = longNames(nameCount)
lNames['Recep Tayyip Erdogan']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-f7ad6b28f099> in <module>()
#       1 lNames = longNames(nameCount)
# ----> 2 lNames['Recep Tayyip Erdogan']
#
# KeyError: 'Recep Tayyip Erdogan'

# %%
name = 'Kohl'
rawTable[rawTable.apply(lambda x: not pd.isnull(x['persons_raw']) and name in x['persons_raw'], axis=1)]
# Out:
#                                                    author        date journal  \
# 24236                                THE ASSOCIATED PRESS  2016-05-13     NYT
# 29160                                                 NaN  2016-06-12     NYT
# 43720                                THE ASSOCIATED PRESS  2016-08-11     NYT
# 44013                                THE ASSOCIATED PRESS  2016-08-11     NYT
# 44029                                             REUTERS  2016-08-11     NYT
# 44030                                             REUTERS  2016-08-11     NYT
# 45198                                             REUTERS  2016-08-12     NYT
# 45390                                             REUTERS  2016-08-13     NYT
# 63264                                THE ASSOCIATED PRESS  2016-09-19     NYT
# 63297                                             REUTERS  2016-09-19     NYT
# 64979                                             REUTERS  2016-09-21     NYT
# 66079                                             REUTERS  2016-09-22     NYT
# 68455                                             REUTERS  2016-09-26     NYT
# 69458                                             REUTERS  2016-09-27     NYT
# 71144                                             REUTERS  2016-09-29     NYT
# 72259                                             REUTERS  2016-09-30     NYT
# 77752                                             REUTERS  2016-10-08     NYT
# 78174                                             REUTERS  2016-10-09     NYT
# 83148                                             REUTERS  2016-10-16     NYT
# 88134                                             REUTERS  2016-10-23     NYT
# 91274                                    CHRISTINE HAUSER  2016-11-08     NYT
# 97607                                LAURA COLLINS-HUGHES  2016-12-18     NYT
# 99523                                                 NaN  2016-01-03     WSJ
# 100563  Suzanne Kapner and Joann S. Lublin and Dana Ma...  2016-01-10     WSJ
# 100751                                   Miriam Gottfried  2016-01-11     WSJ
# 105471                                    Joshua Jamerson  2016-02-04     WSJ
# 106851                                     Suzanne Kapner  2016-02-12     WSJ
# 109242                                        Anne Steele  2016-02-25     WSJ
# 122637                                    Joshua Jamerson  2016-05-12     WSJ
# 135266                                       Sara Germano  2016-07-26     WSJ
# 138224                                    Joshua Jamerson  2016-08-11     WSJ
# 142480                                        Anne Steele  2016-09-08     WSJ
# 152514                                                NaN  2016-11-06     WSJ
# 153371                                    Ezequiel Minaya  2016-11-10     WSJ
# 155328                                    Suzanne Vranica  2016-11-23     WSJ
# 157707                                                NaN  2016-12-09     WSJ
#
#                                                      link  \
# 24236   http://www.nytimes.com/2016/05/13/business/dai...
# 29160   http://www.nytimes.com/2016/06/12/sports/roger...
# 43720   http://www.nytimes.com/aponline/2016/08/11/bus...
# 44013   http://www.nytimes.com/aponline/2016/08/11/bus...
# 44029   http://www.nytimes.com/reuters/2016/08/11/busi...
# 44030   http://www.nytimes.com/reuters/2016/08/11/busi...
# 45198   http://www.nytimes.com/2016/08/12/business/dai...
# 45390   http://www.nytimes.com/reuters/2016/08/13/spor...
# 63264   http://www.nytimes.com/aponline/2016/09/19/bus...
# 63297   http://www.nytimes.com/reuters/2016/09/19/busi...
# 64979   http://www.nytimes.com/reuters/2016/09/21/spor...
# 66079   http://www.nytimes.com/reuters/2016/09/22/spor...
# 68455   http://www.nytimes.com/reuters/2016/09/26/spor...
# 69458   http://www.nytimes.com/reuters/2016/09/26/spor...
# 71144   http://www.nytimes.com/reuters/2016/09/29/spor...
# 72259   http://www.nytimes.com/reuters/2016/09/30/spor...
# 77752   http://www.nytimes.com/reuters/2016/10/08/spor...
# 78174   http://www.nytimes.com/reuters/2016/10/09/spor...
# 83148   http://www.nytimes.com/reuters/2016/10/16/spor...
# 88134   http://www.nytimes.com/reuters/2016/10/23/spor...
# 91274   http://www.nytimes.com/2016/11/09/us/third-bod...
# 97607   http://www.nytimes.com/2016/12/18/theater/revi...
# 99523   http://www.wsj.com/articles/no-11-tcu-roars-ba...
# 100563  http://www.wsj.com/articles/kohls-weighs-next-...
# 100751  http://www.wsj.com/articles/for-kohls-this-sal...
# 105471  http://www.wsj.com/articles/kohls-cuts-outlook...
# 106851  http://www.wsj.com/articles/kohls-eliminates-t...
# 109242  http://www.wsj.com/articles/kohls-profit-falls...
# 122637  http://www.wsj.com/articles/kohls-posts-surpri...
# 135266  http://www.wsj.com/articles/under-armour-reven...
# 138224  http://www.wsj.com/articles/kohls-beats-expect...
# 142480  http://www.wsj.com/articles/kohls-dolls-up-wit...
# 152514  http://www.wsj.com/articles/south-carolina-man...
# 153371  http://www.wsj.com/articles/kohls-profit-rises...
# 155328  http://www.wsj.com/articles/retailers-dominate...
# 157707  http://www.wsj.com/articles/los-angeles-sues-f...
#
#                                section  \
# 24236                     Business Day
# 29160                           Sports
# 43720                     Business Day
# 44013                     Business Day
# 44029                     Business Day
# 44030                     Business Day
# 45198                     Business Day
# 45390                           Sports
# 63264                     Business Day
# 63297                     Business Day
# 64979                           Sports
# 66079                           Sports
# 68455                           Sports
# 69458                           Sports
# 71144                           Sports
# 72259                           Sports
# 77752                           Sports
# 78174                           Sports
# 83148                           Sports
# 88134                           Sports
# 91274                             U.S.
# 97607                          Theater
# 99523     Life,Sports,College Football
# 100563                        Business
# 100751     Markets,Heard on the Street
# 105471               Business,Earnings
# 106851                        Business
# 109242               Business,Earnings
# 122637                        Business
# 135266               Business,Earnings
# 138224               Business,Earnings
# 142480                        Business
# 152514                            U.S.
# 153371               Business,Earnings
# 155328  Business,Media & Marketing,CMO
# 157707                        Business
#
#                                                   summary  \
# 24236   Technology and health care stocks took the lar...
# 29160   On grass, the Swiss Federer lost to the Austri...
# 43720   Stocks that moved substantially or traded heav...
# 44013   Kohl's fiscal second-quarter profit beat analy...
# 44029   All three major U.S. stock indexes closed at r...
# 44030   Kohl's Corp reported a higher-than-expected qu...
# 45198   The department store operator Macy’s, which sa...
# 45390   India crushed West Indies at the third test in...
# 63264   Kohl's plans to hire more than 69,000 addition...
# 63297   Department store operator Kohl's Corp said on ...
# 64979   India have the resources to become the best te...
# 66079   India captain Virat Kohli won the toss and opt...
# 68455   India captain Virat Kohli lavished praise on s...
# 69458   Of all the things that went right in the test ...
# 71144   India test captain Virat Kohli remains sceptic...
# 72259   India captain Virat Kohli won the toss and dec...
# 77752   The normally free-scoring Virat Kohli showed t...
# 78174   Virat Kohli smashed his second test double cen...
# 83148   India's Virat Kohli continued to torment New Z...
# 88134   Virat Kohli hit an unbeaten 154 to make short ...
# 91274   The bodies were removed from the property of T...
# 97607   The work, a trip through Anna Kohler’s memorie...
# 99523   No. 11 TCU Roars Back to Beat No. 15 Oregon, 4...
# 100563  Kohl’s Weighs Next Steps, as Woes Mount As sho...
# 100751  Heard on the Street For Kohl’s, This Sale May ...
# 105471  Kohl’s Cuts Outlook on Soft Sales Kohl’s logge...
# 106851  Kohl’s Eliminates Three Senior Leadership Posi...
# 109242  Kohl’s Profit Falls 20%, Plans to Test Smaller...
# 122637  Kohl’s Posts Surprise Sales Decline Kohl’s pos...
# 135266  Under Armour to Open Sales at Kohl’s Under Arm...
# 138224  Kohl’s Beats Expectations, Helps Lift Retail S...
# 142480  Kohl’s Dolls Up With American Girl Kohl’s will...
# 152514  South Carolina Man Allegedly Killed Seven Peop...
# 153371  Kohl’s Profit Rises on Strong Back-to-School S...
# 155328  Retailers Dominate List of Popular Holiday Ads...
# 157707  Los Angeles Sues Four National Retailers Over ...
#
#                                                     title  \
# 24236      Market Is Mixed After Unemployment Claims Rise
# 29160   Roger Federer Falls on His Favorite Surface to...
# 43720   Macy's, Kohl's and Brinker Climb, While Shake ...
# 44013   Kohl's 2Q Profit Tops Expectations as It Lower...
# 44029   Three Major Indexes End at Records for First T...
# 44030   Kohl's Quarterly Profit Beats Estimates; Share...
# 45198   Stocks End at Record Highs, Bolstered by Retai...
# 45390   Kohli Joy as India Rout West Indies to Win Series
# 63264              Kohl's to Hire 69,000 Seasonal Workers
# 63297   Kohl's to Keep Seasonal Hiring Little Changed ...
# 64979   India Can Be the Best in Test After Bumper Sea...
# 66079   India Skipper Kohli Opts to Bat in Series Open...
# 68455   Kohli Hails 'Priceless' Ashwin After Kanpur He...
# 69458   Pujara's Kanpur Transformation Augurs Well for...
# 71144   Cricket-Kohli Hints at End to India's Dogged D...
# 72259     India Opt to Bat Against New Zealand in Kolkata
# 77752       Careful Kohli Steers India to 267-3 in Indore
# 78174   Cricket-Supreme Kohli, Composed Rahane Punish ...
# 83148   India's Classy Kohli Secures Easy Win Over New...
# 88134     Majestic Kohli Guides India to Seven-Wicket Win
# 91274   Third Body Found in South Carolina After Chain...
# 97607   Review: ‘Mytho? Lure of Wildness’ Teases the S...
# 99523   No. 11 TCU Roars Back to Beat No. 15 Oregon, 4...
# 100563            Kohl’s Weighs Next Steps, as Woes Mount
# 100751       For Kohl’s, This Sale May Be the Best of All
# 105471                  Kohl’s Cuts Outlook on Soft Sales
# 106851  Kohl’s Eliminates Three Senior Leadership Posi...
# 109242  Kohl’s Profit Falls 20%, Plans to Test Smaller...
# 122637              Kohl’s Posts Surprise Revenue Decline
# 135266  Under Armour to Begin Selling Products at Mid-...
# 138224  Kohl’s Beats Expectations, Helps Lift Retail S...
# 142480  Kohl’s Dolls Up With American Girl for Holiday...
# 152514   South Carolina Man Allegedly Killed Seven People
# 153371  Kohl’s Profit Rises on Strong Back-to-School S...
# 155328     Retailers Dominate List of Popular Holiday Ads
# 157707  Los Angeles Sues Four National Retailers Over ...
#
#                                             locations_raw  \
# 24236                                                 NaN
# 29160                                             Germany
# 43720                                                 NaN
# 44013                                                 NaN
# 44029                                                U.S.
# 44030                                                 NaN
# 45198                                                 NaN
# 45390   India,India Rout West Indies,West Indies,St Lucia
# 63264                                                 NaN
# 63297                                       United States
# 64979                                               India
# 66079   India,Green Park Stadium,Kanpur,New Zealand In...
# 68455                                         New Zealand
# 69458                            India,Kanpur,New Zealand
# 71144                                               India
# 72259        Kolkata India,India,Eden Gardens,New Zealand
# 77752                                   India,New Zealand
# 78174                                   India,New Zealand
# 83148      India,Dharamsala,New Zealand India,New Zealand
# 88134         India,Kohli Guides India,Mohali,New Zealand
# 91274                                      South Carolina
# 97607                                               Paris
# 99523                                   Oregon,Alamo Bowl
# 100563                                                NaN
# 100751                                                NaN
# 105471                                                NaN
# 106851                                                NaN
# 109242                                                NaN
# 122637                                                NaN
# 135266                                                NaN
# 138224                                                NaN
# 142480                                                NaN
# 152514  South Carolina Man allegedly kill seven people...
# 153371                                                NaN
# 155328                                                NaN
# 157707                                                NaN
#
#                                         organizations_raw  \
# 24236                                                 NaN
# 29160                                                 NaN
# 43720                               Macy 's,Brinker climb
# 44013                                                 NaN
# 44029                                             Macy 's
# 44030                                                Corp
# 45198                                             Macy 's
# 45390                                                 NaN
# 63264                                                 NaN
# 63297                                    Corp,target Corp
# 64979                                                 NaN
# 66079                                                 NaN
# 68455                                Kanpur Heroics India
# 69458                                                 NaN
# 71144                                drs resistance India
# 72259                                                 NaN
# 77752                          careful Kohli Steers India
# 78174                                                 NaN
# 83148                                                 NaN
# 88134                                                 NaN
# 91274                                                 NaN
# 97607                                                 NaN
# 99523                      TCU roar back,Horned Frogs,TCU
# 100563                                                NaN
# 100751                                                NaN
# 105471                                                NaN
# 106851                                                NaN
# 109242                                              Corp.
# 122637                                                NaN
# 135266                     Mid-Tier Department Store Kohl
# 138224                                                NaN
# 142480                                             Mattel
# 152514                                                NaN
# 153371                                                NaN
# 155328                                   Wal-Mart,Macy 's
# 157707  Los Angeles sue four National Retailers over S...
#
#                                               persons_raw
# 24236                                                Kohl
# 29160   Philipp Kohlschreiber,Dominic Thiem,Roger Fede...
# 43720                                                Kohl
# 44013                                                Kohl
# 44029                                                Kohl
# 44030                                                Kohl
# 45198                                                Kohl
# 45390                               Kohli Joy,Virat Kohli
# 63264                                                Kohl
# 63297                                                Kohl
# 64979                                         Virat Kohli
# 66079                                   Kohli,Virat Kohli
# 68455               Virat Kohli,Kohli,Ravichandran Ashwin
# 69458                Cheteshwar Pujara,Pujara,Virat Kohli
# 71144                                         Virat Kohli
# 72259                         Kane Williamson,Virat Kohli
# 77752                                         Virat Kohli
# 78174    Cricket-Supreme Kohli,Virat Kohli,Ajinkya Rahane
# 83148                            Classy Kohli,Virat Kohli
# 88134                                         Virat Kohli
# 91274                                    Todd C. Kohlhepp
# 97607                           Caleb Hammond,Anna Kohler
# 99523                                     Bram Kohlhausen
# 100563                                               Kohl
# 100751                                               Kohl
# 105471                                               Kohl
# 106851                                               Kohl
# 109242                                               Kohl
# 122637                                               Kohl
# 135266                                        Armour,Kohl
# 138224                                               Kohl
# 142480                                               Kohl
# 152514                                      Todd Kohlhepp
# 153371                                               Kohl
# 155328                                               Kohl
# 157707                             Sears,J.C. Penney,Kohl

# %%
len(pd.unique(rawTable['date']))
# Out:
# 366

# %%
g = rawTable.groupby(['date', 'journal'])

# %%
rawTable.loc[g.groups[('2016-01-01', 'NYT')],'persons_raw']
# Out:
# 0                                      NaN
# 1                                      NaN
# 2                            Zhang Xiaotao
# 3                     Alfred Lord Tennyson
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                              Pamela Paul
# 8                               Jared Goff
# 9                       Clemson Jake Coker
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                          Deshaun Watson
# 23                Villarreal,Bruno Soriano
# 24                         Auston Matthews
# 25                             Kenta Maeda
# 26                                     NaN
# 27                      Eter Nikolaishvili
# 28                                     NaN
# 29                                     NaN
#                       ...
# 103                               Duchenne
# 104                                    NaN
# 105             Andrew Haigh,Tom Courtenay
# 106                                    NaN
# 107    Juan F. Thompson,Hunter S. Thompson
# 108          Corvette Jerry Seinfeld,Obama
# 109                         Hassan Rouhani
# 110                                    NaN
# 111             Marco Rubio,Chris Christie
# 112               Ted Cruz,Cruz,Ben Carson
# 113                                    NaN
# 114                                    NaN
# 115                                    NaN
# 116                          Blake Bortles
# 117                     Hissène Habré,Chad
# 118                                    NaN
# 119                                    NaN
# 120                                    NaN
# 121                                    NaN
# 122                        Connor Cummings
# 123                            Eide Marine
# 124                                    NaN
# 125                                    NaN
# 126                                    NaN
# 127                                    NaN
# 128                                    NaN
# 129                         Shohret Hoshur
# 130                       Edward Hugh,Hugh
# 131               Weissman,Murray Weissman
# 132                                    NaN
# Name: persons_raw, dtype: object
